# %%
#Pandas--Google Play Store App Analysis
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)

# %%
#Load the content of csv file of Google Play Store
df=pd.read_csv("D:\\KVR-NUMPY-11AM\\googleplaystore.csv")
print(df)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# 10. Finnd the Total Number of Appa having 5 Star rating
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Rating']
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df['Rating']==5.0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
df[df['Rating']==5.0]
# Out:
#                                               App   Category  Rating Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15
# 612                 American Girls Mobile Numbers     DATING     5.0       5
# 615                                  Awake Dating     DATING     5.0       2
# 633                         Spine- The dating app     DATING     5.0       5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0       6
# ...                                           ...        ...     ...     ...
# 10721                           Mad Dash Fo' Cash       GAME     5.0      14
# 10742                       GKPB FP Online Church  LIFESTYLE     5.0      32
# 10776                            Monster Ride Pro       GAME     5.0       1
# 10820                             Fr. Daoud Lamei     FAMILY     5.0      22
# 10837            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0       4
#
# ...

# %%
print("Total Number of Apps having 5 Star rating=",len(df[df['Rating']==5.0]))
# Out:
# Total Number of Apps having 5 Star rating= 274

# %%
df[df['Rating']==5.0]['App']
# Out:
# 329                    Hojiboy Tojiboyev Life Hacks
# 612                   American Girls Mobile Numbers
# 615                                    Awake Dating
# 633                           Spine- The dating app
# 636      Girls Live Talk - Free Text and Video Chat
#                             ...
# 10721                             Mad Dash Fo' Cash
# 10742                         GKPB FP Online Church
# 10776                              Monster Ride Pro
# 10820                               Fr. Daoud Lamei
# 10837              Fr. Mike Schmitz Audio Teachings
# Name: App, Length: 274, dtype: object

# %%
# 11.Find Average value of Reviews
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
print(df['Reviews'].dtype)
# Out:
# object

# %%
#convert 'Reviews' type as float type (object--->float) 
df['Reviews'].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 #convert 'Reviews' type as float type (object--->float)
# ----> 2 df['Reviews'].astype("float")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df[df['Reviews']=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df['Reviews']=df['Reviews'].replace("3.0M",3000000)
df[df['Reviews']==3000000]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
# Convert "Reviews" type as float type (object-->float)
df['Reviews']=df['Reviews'].astype("float")
print(df['Reviews'].dtype)
# Out:
# float64

# %%
df['Reviews'].mean()
# Out:
# 444388.6535374965

# %%
print("Average values of Reviews=",df['Reviews'].mean())
# Out:
# Average values of Reviews= 444388.6535374965

# %%
# 12. Find Total Number of free and Paid Apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
print("Number of Free Apps=",len(df[df["Type"]=="Free"]))
# Out:
# Number of Free Apps= 10039

# %%
print("Number of Paid App=",len(df[df["Type"]=="Paid"]))
# Out:
# Number of Paid App= 800

# %%
df["Type"].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %%
# 13. which App has maxium Reviews?
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Reviews']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
df['Reviews'].max()
# Out:
# 78158306.0

# %%
df['Reviews'].max()==df['Reviews']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[df['Reviews'].max()==df['Reviews']]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
df[df['Reviews'].max()==df['Reviews']]["App"]
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %%
print("App Has Maximum Reviews=",df[df['Reviews'].max()==df['Reviews']]["App"])
# Out:
# App Has Maximum Reviews= 2544    Facebook
# Name: App, dtype: object

# %%
# 14. Display Top 5 Apps Having Highest Reviews
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
ind=df['Reviews'].sort_values(ascending=False).head().index

# %%
df.iloc[ind]["App"]
# Out:
# 2544              Facebook
# 3943              Facebook
# 336     WhatsApp Messenger
# 381     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
#15. Find Average Rating of Free and Paid Apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df["Type"]
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
df.groupby("Type")["Rating"].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
#16.Display Top  5 Apps Having Maximum Installs
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
print(df['Installs'].dtype)
# Out:
# object

# %%
#Convert dtype of 'df['Installs'] ' into int type by using astype
df['Installs'].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 #Convert dtype of 'df['Installs'] ' into int type by using astype
# ----> 2 df['Installs'].astype("int")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...

# %%
df["installs_1"]=df['Installs'].str.replace(",","")

df["installs_1"]
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: installs_1, Length: 10841, dtype: object

# %%
df["installs_1"]=df["installs_1"].str.replace("+","")

df["installs_1"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: installs_1, Length: 10841, dtype: object

# %%
df["installs_1"].dtype
# Out:
# dtype('O')

# %%
df["installs_1"]=df["installs_1"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df["installs_1"]=df["installs_1"].astype("int")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df[df["installs_1"]=='Free']
# Out:
#                                            App Category  Rating    Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver installs_1
# 10472       1.0.19  4.0 and up         NaN       Free

# %%
df["installs_1"]=df["installs_1"].str.replace("Free","0")

df["installs_1"]=df["installs_1"].astype("int")

# %%
indices=df["installs_1"].sort_values(ascending=False).head().index

# %%
df.iloc[indices]["App"]
# Out:
# 3896                              Subway Surfers
# 3943                                    Facebook
# 335     Messenger – Text and Video Chat for Free
# 3523                                Google Drive
# 3565                                Google Drive
# Name: App, dtype: object

# %%
df.iloc[indices]["App"].values
# Out:
# array(['Subway Surfers', 'Facebook',
#        'Messenger – Text and Video Chat for Free', 'Google Drive',
#        'Google Drive'], dtype=object)
